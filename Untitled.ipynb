# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import numpy as np

# %%
train_df = pd.read_csv('titanic/train.csv')
test_df = pd.read_csv('titanic/test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train_df['Sex'] = train_df['Sex'].replace({'female': 0, 'male': 1})
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_25855/992010080.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Sex'] = train_df['Sex'].replace({'female': 0, 'male': 1})

# %%
train_df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
train_df.drop(columns= ['Ticket'], inplace=True)

# %%
grouped_by_class = train_df.T.groupby(['Pclass'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[361], line 1
# ----> 1 grouped_by_class = train_df.T.groupby(['Pclass'])
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:9170, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9167 if level is None and by is None:
#    9168     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9170 return DataFrameGroupBy(
#    9171     obj=self,
#    9172     keys=by,
#    9173     axis=axis,
#    9174     level=level,
#    9175     as_index=as_index,
#    9176     sort=sort,
#    9177     group_keys=group_keys,
#    9178     observed=observed,
#    9179     dropna=dropna,
#    9180 )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Pclass'

# %%
train_df.columns = train_df.columns.str.strip()

# %%
train_df.set_index('PassengerId', inplace=True)

# %%
grouped_by_class = train_df.groupby(['Pclass'])

# %%
for name, group in grouped_by_class:
    print("Group:", name)
    print(group)
# Out:
# Group: (1,)
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name  Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 7                                      McCarthy, Mr. Timothy J    1  54.0
# 12                                    Bonnell, Miss. Elizabeth    0  58.0
# 24                                Sloper, Mr. William Thompson    1  28.0
# ...                                                        ...  ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)    0  47.0
# 873                                   Carlsson, Mr. Frans Olof    1  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    0  56.0
# 888                               Graham, Miss. Margaret Edith    0  19.0
# 890                                      Behr, Mr. Karl Howell    1  26.0
#
#              SibSp  Parch     Fare        Cabin Embarked
# PassengerId
# 2                1      0  71.2833          C85        C
# 4                1      0  53.1000         C123        S
# 7                0      0  51.8625          E46        S
# 12               0      0  26.5500         C103        S
# 24               0      0  35.5000           A6        S
# ...            ...    ...      ...          ...      ...
# 872              1      1  52.5542          D35        S
# 873              0      0   5.0000  B51 B53 B55        S
# 880              0      1  83.1583          C50        C
# 888              0      0  30.0000          B42        S
# 890              0      0  30.0000         C148        C
#
# [216 rows x 10 columns]
# Group: (2,)
#              Survived  Pclass                                          Name  \
# PassengerId
# 10                  1       2           Nasser, Mrs. Nicholas (Adele Achem)
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
# 18                  1       2                  Williams, Mr. Charles Eugene
# 21                  0       2                          Fynney, Mr. Joseph J
# 22                  1       2                         Beesley, Mr. Lawrence
# ...               ...     ...                                           ...
# 867                 1       2                  Duran y More, Miss. Asuncion
# 875                 1       2         Abelson, Mrs. Samuel (Hannah Wizosky)
# 881                 1       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 884                 0       2                 Banfield, Mr. Frederick James
# 887                 0       2                         Montvila, Rev. Juozas
#
#              Sex   Age  SibSp  Parch     Fare Cabin Embarked
# PassengerId
# 10             0  14.0      1      0  30.0708   NaN        C
# 16             0  55.0      0      0  16.0000   NaN        S
# 18             1   NaN      0      0  13.0000   NaN        S
# 21             1  35.0      0      0  26.0000   NaN        S
# 22             1  34.0      0      0  13.0000   D56        S
# ...          ...   ...    ...    ...      ...   ...      ...
# 867            0  27.0      1      0  13.8583   NaN        C
# 875            0  28.0      1      0  24.0000   NaN        C
# 881            0  25.0      0      1  26.0000   NaN        S
# 884            1  28.0      0      0  10.5000   NaN        S
# 887            1  27.0      0      0  13.0000   NaN        S
#
# [184 rows x 10 columns]
# Group: (3,)
#              Survived  Pclass                                      Name  Sex  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris    1
# 3                   1       3                    Heikkinen, Miss. Laina    0
# 5                   0       3                  Allen, Mr. William Henry    1
# 6                   0       3                          Moran, Mr. James    1
# 8                   0       3            Palsson, Master. Gosta Leonard    1
# ...               ...     ...                                       ...  ...
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika    0
# 885                 0       3                    Sutehall, Mr. Henry Jr    1
# 886                 0       3      Rice, Mrs. William (Margaret Norton)    0
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"    0
# 891                 0       3                       Dooley, Mr. Patrick    1
#
#               Age  SibSp  Parch     Fare Cabin Embarked
# PassengerId
# 1            22.0      1      0   7.2500   NaN        S
# 3            26.0      0      0   7.9250   NaN        S
# 5            35.0      0      0   8.0500   NaN        S
# 6             NaN      0      0   8.4583   NaN        Q
# 8             2.0      3      1  21.0750   NaN        S
# ...           ...    ...    ...      ...   ...      ...
# 883          22.0      0      0  10.5167   NaN        S
# 885          25.0      0      0   7.0500   NaN        S
# 886          39.0      0      5  29.1250   NaN        Q
# 889           NaN      1      2  23.4500   NaN        S
# 891          32.0      0      0   7.7500   NaN        Q
#
# [491 rows x 10 columns]

# %%
pclass_df = pd.concat(dict(list(grouped_by_class)), axis=0)
pclass_df
# Out:
#                Survived  Pclass  \
#   PassengerId
# 1 2                   1       1
#   4                   1       1
#   7                   0       1
#   12                  1       1
#   24                  1       1
# ...                 ...     ...
# 3 883                 0       3
#   885                 0       3
#   886                 0       3
#   889                 0       3
#   891                 0       3
#
#                                                             Name  Sex   Age  \
#   PassengerId
# 1 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
#   4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
#   7                                      McCarthy, Mr. Timothy J    1  54.0
#   12                                    Bonnell, Miss. Elizabeth    0  58.0
#   24                                Sloper, Mr. William Thompson    1  28.0
# ...                                                          ...  ...   ...
# 3 883                               Dahlberg, Miss. Gerda Ulrika    0  22.0
#   885                                     Sutehall, Mr. Henry Jr    1  25.0
#   886                       Rice, Mrs. William (Margaret Norton)    0  39.0
#   889                   Johnston, Miss. Catherine Helen "Carrie"    0   NaN
#   891                                        Dooley, Mr. Patrick    1  32.0
#
#                SibSp  Parch     Fare Cabin Embarked
#   PassengerId
# 1 2                1      0  71.2833   C85        C
#   4                1      0  53.1000  C123        S
#   7                0      0  51.8625   E46        S
#   12               0      0  26.5500  C103        S
#   24               0      0  35.5000    A6        S
# ...              ...    ...      ...   ...      ...
# 3 883              0      0  10.5167   NaN        S
#   885              0      0   7.0500   NaN        S
#   886              0      5  29.1250   NaN        Q
#   889              1      2  23.4500   NaN        S
#   891              0      0   7.7500   NaN        Q
#
# [891 rows x 10 columns]

# %%
pclass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 891 entries, (1, 2) to (3, 891)
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    int64
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 111.7+ KB

# %%
def list_comp(df, a, b, new_column_name):
    df[new_column_name] = df.apply(lambda row: 0 if row[a] >0 or row[b] > 0 else 1, axis=1)
    return df

# %%
list_comp(train_df, 'SibSp', 'Parch', 'Solo')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# 887                                      Montvila, Rev. Juozas    1  27.0
# 888                               Graham, Miss. Margaret Edith    0  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"    0   NaN
# 890                                      Behr, Mr. Karl Howell    1  26.0
# 891                                        Dooley, Mr. Patrick    1  32.0
#
#              SibSp  Parch     Fare Cabin Embarked  Solo
# PassengerId
# 1                1      0   7.2500   NaN        S     0
# 2                1      0  71.2833   C85        C     0
# 3                0      0   7.9250   NaN        S     1
# 4                1      0  53.1000  C123        S     0
# 5                0      0   8.0500   NaN        S     1
# ...            ...    ...      ...   ...      ...   ...
# 887              0      0  13.0000   NaN        S     1
# 888              0      0  30.0000   B42        S     1
# 889              1      2  23.4500   NaN        S     0
# 890              0      0  30.0000  C148        C     1
# 891              0      0   7.7500   NaN        Q     1
#
# [891 rows x 11 columns]

# %% [markdown]
# Changing locations to numbers

# %%
train_df['Embarked'] = train_df['Embarked'].replace({'C': 0, 'S': 1, 'Q': 2})
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_25855/2153412030.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Embarked'] = train_df['Embarked'].replace({'C': 0, 'S': 1, 'Q': 2})

# %%
train_df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
def create_pattern_column(df, column_name, patterns, new_column_name='Pattern'):
    """ 
    Create a new column based on patterns in a string column.

    Parameters:
    df (DataFrame): Input DataFrame.
    column_name (str): Name of the column containing strings to search.
    patterns (list of tuples): List of tuples where each tuple contains a pattern (regular expression) and its corresponding label.
    new_column_name (str, optional): Name of the new column to be created. Default is Pattern.
    Returns:
    DataFrame: DataFrame with the new pattern column added.
    """
    # Define a function to check if any pattern is present in the text
    def check_patterns(text):
        if isinstance(text, str):
            for pattern, value in patterns:
                if re.search(pattern, text):
                    return value
            return 0
        else:   
            return 0

    # Apply the function to each row of the specified column
    df[new_column_name] = df[column_name].astype(str).apply(check_patterns)

    return df

# %%
cabin_floor = [
    (r'A', 1),
    (r'B', 2),
    (r'C', 3),
    (r'D', 4),
    (r'E', 5),
    (r'F', 6),
    (r'G', 7),
    (r'N', 0)
]

create_pattern_column(train_df, 'Cabin', cabin_floor, 'Floor')
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# 887                                      Montvila, Rev. Juozas    1  27.0
# 888                               Graham, Miss. Margaret Edith    0  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"    0   NaN
# 890                                      Behr, Mr. Karl Howell    1  26.0
# 891                                        Dooley, Mr. Patrick    1  32.0
#
#              SibSp  Parch     Fare Cabin  Embarked  Solo  Floor
# PassengerId
# 1                1      0   7.2500   NaN       1.0     0      0
# 2                1      0  71.2833   C85       0.0     0      3
# 3                0      0   7.9250   NaN       1.0     1      0
# 4                1      0  53.1000  C123       1.0     0      3
# 5                0      0   8.0500   NaN       1.0     1      0
# ...            ...    ...      ...   ...       ...   ...    ...
# 887              0      0  13.0000   NaN       1.0     1      0
# 888              0      0  30.0000   B42       1.0     1      2
# 889              1      2  23.4500   NaN       1.0     0      0
# 890              0      0  30.0000  C148       0.0     1      3
# 891              0      0   7.7500   NaN       2.0     1      0
#
# [891 rows x 12 columns]

# %%
def extract_title(name):
    match = re.search(r'\b(\w+\.)', name)
    return match.group(1) if match else None

# %%
train_df['Title'] = train_df['Name'].apply(extract_title)
train_df['Title'].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# Countess.      1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
mean_ages = train_df.groupby('Title')['Age'].mean()
mean_ages
# Out:
# Title
# Capt.        70.000000
# Col.         58.000000
# Countess.    33.000000
# Don.         40.000000
# Dr.          42.000000
# Jonkheer.    38.000000
# Lady.        48.000000
# Major.       48.500000
# Master.       4.574167
# Miss.        21.773973
# Mlle.        24.000000
# Mme.         24.000000
# Mr.          32.368090
# Mrs.         35.898148
# Ms.          28.000000
# Rev.         43.166667
# Sir.         49.000000
# Name: Age, dtype: float64

# %%
 def fill_missing_age(row):
    if pd.isnull(row['Age']):
        return mean_ages[row['Title']]
    return row['Age']

# %%
train_df['Age'] = train_df.apply(fill_missing_age, axis=1)
train_df['Age'].value_counts()
# Out:
# Age
# 32.368090    119
# 21.773973     36
# 24.000000     30
# 22.000000     27
# 18.000000     26
#             ...
# 14.500000      1
# 70.500000      1
# 12.000000      1
# 36.500000      1
# 74.000000      1
# Name: count, Length: 92, dtype: int64

# %%
train_df[train_df['Title'] == 'Dr.']
# Out:
#              Survived  Pclass                           Name  Sex   Age  \
# PassengerId
# 246                 0       1    Minahan, Dr. William Edward    1  44.0
# 318                 0       2           Moraweck, Dr. Ernest    1  54.0
# 399                 0       2               Pain, Dr. Alfred    1  23.0
# 633                 1       1      Stahelin-Maeglin, Dr. Max    1  32.0
# 661                 1       1  Frauenthal, Dr. Henry William    1  50.0
# 767                 0       1      Brewe, Dr. Arthur Jackson    1  42.0
# 797                 1       1    Leader, Dr. Alice (Farnham)    0  49.0
#
#              SibSp  Parch      Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 246              2      0   90.0000   C78       2.0     0      3   Dr.
# 318              0      0   14.0000   NaN       1.0     1      0   Dr.
# 399              0      0   10.5000   NaN       1.0     1      0   Dr.
# 633              0      0   30.5000   B50       0.0     1      2   Dr.
# 661              2      0  133.6500   NaN       1.0     0      0   Dr.
# 767              0      0   39.6000   NaN       0.0     1      0   Dr.
# 797              0      0   25.9292   D17       1.0     1      4   Dr.

# %%
train_df[train_df['Title'] == 'Rev.']
# Out:
#              Survived  Pclass                               Name  Sex   Age  \
# PassengerId
# 150                 0       2  Byles, Rev. Thomas Roussel Davids    1  42.0
# 151                 0       2         Bateman, Rev. Robert James    1  51.0
# 250                 0       2      Carter, Rev. Ernest Courtenay    1  54.0
# 627                 0       2     Kirkland, Rev. Charles Leonard    1  57.0
# 849                 0       2                  Harper, Rev. John    1  28.0
# 887                 0       2              Montvila, Rev. Juozas    1  27.0
#
#              SibSp  Parch    Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 150              0      0  13.000   NaN       1.0     1      0  Rev.
# 151              0      0  12.525   NaN       1.0     1      0  Rev.
# 250              1      0  26.000   NaN       1.0     0      0  Rev.
# 627              0      0  12.350   NaN       2.0     1      0  Rev.
# 849              0      1  33.000   NaN       1.0     0      0  Rev.
# 887              0      0  13.000   NaN       1.0     1      0  Rev.

# %%
train_df[train_df['Title'] == 'Mlle.']
# Out:
#              Survived  Pclass  \
# PassengerId
# 642                 1       1
# 711                 1       1
#
#                                                          Name  Sex   Age  \
# PassengerId
# 642                                      Sagesser, Mlle. Emma    0  24.0
# 711          Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")    0  24.0
#
#              SibSp  Parch     Fare Cabin  Embarked  Solo  Floor  Title
# PassengerId
# 642              0      0  69.3000   B35       0.0     1      2  Mlle.
# 711              0      0  49.5042   C90       0.0     1      3  Mlle.

# %%
train_df[train_df['Title'] == 'Major.']
# Out:
#              Survived  Pclass                               Name  Sex   Age  \
# PassengerId
# 450                 1       1     Peuchen, Major. Arthur Godfrey    1  52.0
# 537                 0       1  Butt, Major. Archibald Willingham    1  45.0
#
#              SibSp  Parch   Fare Cabin  Embarked  Solo  Floor   Title
# PassengerId
# 450              0      0  30.50  C104       1.0     1      3  Major.
# 537              0      0  26.55   B38       1.0     1      2  Major.

# %%
train_df[train_df['Title'] == 'Col.']
# Out:
#              Survived  Pclass                                 Name  Sex   Age  \
# PassengerId
# 648                 1       1  Simonius-Blumer, Col. Oberst Alfons    1  56.0
# 695                 0       1                      Weir, Col. John    1  60.0
#
#              SibSp  Parch   Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 648              0      0  35.50   A26       0.0     1      1  Col.
# 695              0      0  26.55   NaN       1.0     1      0  Col.

# %%
train_df[train_df['Title'] == 'Countess.']
# Out:
#              Survived  Pclass  \
# PassengerId
# 760                 1       1
#
#                                                           Name  Sex   Age  \
# PassengerId
# 760          Rothes, the Countess. of (Lucy Noel Martha Dye...    0  33.0
#
#              SibSp  Parch  Fare Cabin  Embarked  Solo  Floor      Title
# PassengerId
# 760              0      0  86.5   B77       1.0     1      2  Countess.

# %%
train_df[train_df['Title'] == 'Capt.']
# Out:
#              Survived  Pclass                          Name  Sex   Age  SibSp  \
# PassengerId
# 746                 0       1  Crosby, Capt. Edward Gifford    1  70.0      1
#
#              Parch  Fare Cabin  Embarked  Solo  Floor  Title
# PassengerId
# 746              1  71.0   B22       1.0     0      2  Capt.

# %%
train_df[train_df['Title'] == 'Ms.']
# Out:
#              Survived  Pclass                       Name  Sex   Age  SibSp  \
# PassengerId
# 444                 1       2  Reynaldo, Ms. Encarnacion    0  28.0      0
#
#              Parch  Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 444              0  13.0   NaN       1.0     1      0   Ms.

# %%
train_df[train_df['Title'] == 'Sir.']
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 600                 1       1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
#
#              Sex   Age  SibSp  Parch     Fare Cabin  Embarked  Solo  Floor  \
# PassengerId
# 600            1  49.0      1      0  56.9292   A20       0.0     0      1
#
#             Title
# PassengerId
# 600          Sir.

# %%
train_df[train_df['Title'] == 'Lady.']
# Out:
#              Survived  Pclass  \
# PassengerId
# 557                 1       1
#
#                                                           Name  Sex   Age  \
# PassengerId
# 557          Duff Gordon, Lady. (Lucille Christiana Sutherl...    0  48.0
#
#              SibSp  Parch  Fare Cabin  Embarked  Solo  Floor  Title
# PassengerId
# 557              1      0  39.6   A16       0.0     0      1  Lady.

# %%
train_df[train_df['Title'] == 'Mme.']
# Out:
#              Survived  Pclass                           Name  Sex   Age  \
# PassengerId
# 370                 1       1  Aubart, Mme. Leontine Pauline    0  24.0
#
#              SibSp  Parch  Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 370              0      0  69.3   B35       0.0     1      2  Mme.

# %%
train_df[train_df['Title'] == 'Don.']
# Out:
#              Survived  Pclass                      Name  Sex   Age  SibSp  \
# PassengerId
# 31                  0       1  Uruchurtu, Don. Manuel E    1  40.0      0
#
#              Parch     Fare Cabin  Embarked  Solo  Floor Title
# PassengerId
# 31               0  27.7208   NaN       0.0     1      0  Don.

# %%
train_df[train_df['Title'] == 'Jonkheer.']
# Out:
#              Survived  Pclass                             Name  Sex   Age  \
# PassengerId
# 823                 0       1  Reuchlin, Jonkheer. John George    1  38.0
#
#              SibSp  Parch  Fare Cabin  Embarked  Solo  Floor      Title
# PassengerId
# 823              0      0   0.0   NaN       1.0     1      0  Jonkheer.

# %%
Title = [
    (r'Mr.', 1),
    (r'Miss.', 2),
    (r'Mrs.', 3),
    (r'Master.', 4),
    (r'Dr.', 5),
    (r'Rev.', 5),
    (r'Mlle.', 5),
    (r'Major.', 5),
    (r'Col.', 5),
    (r'Countess.', 5),
    (r'Capt.', 5),
    (r'Ms.', 5),
    (r'Sir.', 5),
    (r'Lady.', 5),
    (r'Mme.', 5),
    (r'Don.', 5),
    (r'Jonkheer.', 5)
]

create_pattern_column(train_df, 'Title', Title, 'Title_category')
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 3                                       Heikkinen, Miss. Laina    0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 5                                     Allen, Mr. William Henry    1
# ...                                                        ...  ...
# 887                                      Montvila, Rev. Juozas    1
# 888                               Graham, Miss. Margaret Edith    0
# 889                   Johnston, Miss. Catherine Helen "Carrie"    0
# 890                                      Behr, Mr. Karl Howell    1
# 891                                        Dooley, Mr. Patrick    1
#
#                    Age  SibSp  Parch     Fare Cabin  Embarked  Solo  Floor  \
# PassengerId
# 1            22.000000      1      0   7.2500   NaN       1.0     0      0
# 2            38.000000      1      0  71.2833   C85       0.0     0      3
# 3            26.000000      0      0   7.9250   NaN       1.0     1      0
# 4            35.000000      1      0  53.1000  C123       1.0     0      3
# 5            35.000000      0      0   8.0500   NaN       1.0     1      0
# ...                ...    ...    ...      ...   ...       ...   ...    ...
# 887          27.000000      0      0  13.0000   NaN       1.0     1      0
# 888          19.000000      0      0  30.0000   B42       1.0     1      2
# 889          21.773973      1      2  23.4500   NaN       1.0     0      0
# 890          26.000000      0      0  30.0000  C148       0.0     1      3
# 891          32.000000      0      0   7.7500   NaN       2.0     1      0
#
#              Title  Title_category
# PassengerId
# 1              Mr.               1
# 2             Mrs.               1
# 3            Miss.               2
# 4             Mrs.               1
# 5              Mr.               1
# ...            ...             ...
# 887           Rev.               5
# 888          Miss.               2
# 889          Miss.               2
# 890            Mr.               1
# 891            Mr.               1
#
# [891 rows x 14 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    int64
#  4   Age             891 non-null    float64
#  5   SibSp           891 non-null    int64
#  6   Parch           891 non-null    int64
#  7   Fare            891 non-null    float64
#  8   Cabin           204 non-null    object
#  9   Embarked        889 non-null    float64
#  10  Solo            891 non-null    int64
#  11  Floor           891 non-null    int64
#  12  Title           891 non-null    object
#  13  Title_category  891 non-null    int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 104.4+ KB

# %%
train_df.drop(columns=['Cabin', 'Name', 'Title'], inplace=True)

# %%
train_df['Child'] = train_df['Age'].apply(lambda x: 0 if x >= 18 else 1)
train_df
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500
# 2                   1       1    0  38.000000      1      0  71.2833
# 3                   1       3    0  26.000000      0      0   7.9250
# 4                   1       1    0  35.000000      1      0  53.1000
# 5                   0       3    1  35.000000      0      0   8.0500
# ...               ...     ...  ...        ...    ...    ...      ...
# 887                 0       2    1  27.000000      0      0  13.0000
# 888                 1       1    0  19.000000      0      0  30.0000
# 889                 0       3    0  21.773973      1      2  23.4500
# 890                 1       1    1  26.000000      0      0  30.0000
# 891                 0       3    1  32.000000      0      0   7.7500
#
#              Embarked  Solo  Floor  Title_category  Child
# PassengerId
# 1                 1.0     0      0               1      0
# 2                 0.0     0      3               1      0
# 3                 1.0     1      0               2      0
# 4                 1.0     0      3               1      0
# 5                 1.0     1      0               1      0
# ...               ...   ...    ...             ...    ...
# 887               1.0     1      0               5      0
# 888               1.0     1      2               2      0
# 889               1.0     0      0               2      0
# 890               0.0     1      3               1      0
# 891               2.0     1      0               1      0
#
# [891 rows x 12 columns]

# %%
train_df[train_df['Embarked'].isnull()]
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch  Fare  Embarked  Solo  \
# PassengerId
# 62                  1       1    0  38.0      0      0  80.0       NaN     1
# 830                 1       1    0  62.0      0      0  80.0       NaN     1
#
#              Floor  Title_category  Child
# PassengerId
# 62               2               2      0
# 830              2               1      0

# %%
sns.heatmap(train_df.corr())
# Out:
# <Axes: >

# %%
train_df.to_csv('./train_cleaned.csv')
