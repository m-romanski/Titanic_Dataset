# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import numpy as np

# %%
train_df = pd.read_csv('titanic/train.csv')
test_df = pd.read_csv('titanic/test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df['Sex'] = train_df['Sex'].replace({'female': 0, 'male': 1})
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_8326/992010080.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Sex'] = train_df['Sex'].replace({'female': 0, 'male': 1})

# %%
train_df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
train_df.drop(columns= ['Ticket'], inplace=True)

# %%
grouped_by_class = train_df.T.groupby(['Pclass'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 grouped_by_class = train_df.T.groupby(['Pclass'])
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:9170, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9167 if level is None and by is None:
#    9168     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9170 return DataFrameGroupBy(
#    9171     obj=self,
#    9172     keys=by,
#    9173     axis=axis,
#    9174     level=level,
#    9175     as_index=as_index,
#    9176     sort=sort,
#    9177     group_keys=group_keys,
#    9178     observed=observed,
#    9179     dropna=dropna,
#    9180 )
#
# ...

# %%
train_df.columns = train_df.columns.str.strip()

# %%
train_df.set_index('PassengerId', inplace=True)

# %%
grouped_by_class = train_df.groupby(['Pclass'])

# %%
for name, group in grouped_by_class:
    print("Group:", name)
    print(group)
# Out:
# Group: (1,)
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name  Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 7                                      McCarthy, Mr. Timothy J    1  54.0
# 12                                    Bonnell, Miss. Elizabeth    0  58.0
# 24                                Sloper, Mr. William Thompson    1  28.0
# ...                                                        ...  ...   ...
# ...

# %%
grouped_df = pd.concat(dict(list(grouped_by_class)), axis=0)
grouped_df
# Out:
#                Survived  Pclass  \
#   PassengerId
# 1 2                   1       1
#   4                   1       1
#   7                   0       1
#   12                  1       1
#   24                  1       1
# ...                 ...     ...
# 3 883                 0       3
#   885                 0       3
#   886                 0       3
#   889                 0       3
#   891                 0       3
#
#                                                             Name  Sex   Age  \
#   PassengerId
# 1 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
#   4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
#   7                                      McCarthy, Mr. Timothy J    1  54.0
#   12                                    Bonnell, Miss. Elizabeth    0  58.0
#   24                                Sloper, Mr. William Thompson    1  28.0
# ...                                                          ...  ...   ...
# ...

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 891 entries, (1, 2) to (3, 891)
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    int64
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 111.7+ KB

# %%
def list_comp(df, a, b, new_column_name):
    df[new_column_name] = df.apply(lambda row: 0 if row[a] == 1 or row[b] == 1 else 1, axis=1)
    return df

# %%
list_comp(train_df, 'SibSp', 'Parch', 'Solo')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
train_df['Child'] = np.where(train_df['Age'] < 18, 1, 0)
train_df.loc[pd.isnull(train_df['Age']), 'Child'] = None
train_df['Child'].value_counts()
# Out:
# Child
# 0.0    601
# 1.0    113
# Name: count, dtype: int64

# %% [markdown]
# Changing locations to numbers

# %%
train_df['Embarked'] = train_df['Embarked'].replace({'C': 0, 'S': 1, 'Q': 2})
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_8326/2153412030.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Embarked'] = train_df['Embarked'].replace({'C': 0, 'S': 1, 'Q': 2})

# %%
train_df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
def create_pattern_column(df, column_name, patterns, new_column_name='Pattern'):
    """ 
    Create a new column based on patterns in a string column.

    Parameters:
    df (DataFrame): Input DataFrame.
    column_name (str): Name of the column containing strings to search.
    patterns (list of tuples): List of tuples where each tuple contains a pattern (regular expression) and its corresponding label.
    new_column_name (str, optional): Name of the new column to be created. Default is Pattern.
    Returns:
    DataFrame: DataFrame with the new pattern column added.
    """
    # Define a function to check if any pattern is present in the text
    def check_patterns(text):
        if isinstance(text, str):
            for pattern, value in patterns:
                if re.search(pattern, text):
                    return value
            return 0
        else:   
            return 0

    # Apply the function to each row of the specified column
    df[new_column_name] = df[column_name].astype(str).apply(check_patterns)

    return df

# %%
cabin_floor = [
    (r'A', 1),
    (r'B', 2),
    (r'C', 3),
    (r'D', 4),
    (r'E', 5),
    (r'F', 6),
    (r'G', 7),
    (r'N', 0)
]

create_pattern_column(train_df, 'Cabin', cabin_floor, 'Floor')
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    int64
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    float64
#  10  Solo      891 non-null    int64
#  11  Floor     891 non-null    int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 90.5+ KB

# %%
train_df.drop(columns='Cabin', inplace=True)

# %%
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...
